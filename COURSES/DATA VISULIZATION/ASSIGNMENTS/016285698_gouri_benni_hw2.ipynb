# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Iris.csv")

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df.head(5)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.tail(5)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
df.mode()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.0           3.0            1.5           0.2
# 1      2            NaN           NaN            NaN           NaN
# 2      3            NaN           NaN            NaN           NaN
# 3      4            NaN           NaN            NaN           NaN
# 4      5            NaN           NaN            NaN           NaN
# ..   ...            ...           ...            ...           ...
# 145  146            NaN           NaN            NaN           NaN
# 146  147            NaN           NaN            NaN           NaN
# 147  148            NaN           NaN            NaN           NaN
# 148  149            NaN           NaN            NaN           NaN
# 149  150            NaN           NaN            NaN           NaN
#
#              Species
# 0        Iris-setosa
# 1    Iris-versicolor
# 2     Iris-virginica
# 3                NaN
# 4                NaN
# ..               ...
# ...

# %%
df.isnull()
# Out:
#         Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0    False          False         False          False         False    False
# 1    False          False         False          False         False    False
# 2    False          False         False          False         False    False
# 3    False          False         False          False         False    False
# 4    False          False         False          False         False    False
# ..     ...            ...           ...            ...           ...      ...
# 145  False          False         False          False         False    False
# 146  False          False         False          False         False    False
# 147  False          False         False          False         False    False
# 148  False          False         False          False         False    False
# 149  False          False         False          False         False    False
#
# [150 rows x 6 columns]

# %%
#The data set has no null values
df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
#1. (25%) Using Python or Tableau Matplotlib to implement Ch 2 concepts 
#explain what you find from the given data or your own data. Please provide source code and visualization results. 
fig, ax = plt.subplots(1,1, figsize = (9,9))
bar_colors = ['tab:red', 'tab:blue', 'tab:orange']
ax.bar(df['Species'],df['PetalWidthCm'], color = bar_colors)
ax.set_title('BAR PLOT')
# Out:
# Text(0.5, 1.0, 'BAR PLOT')

# %%
fig,ax0 = plt.subplots(1,1, figsize=(10,7))
#Changing the Colour
ax0.scatter(x = df['PetalLengthCm'],y = df['SepalWidthCm'],c=df.Species.astype('category').cat.codes, marker = '^')

# %%
fig, ax1 = plt.subplots(1,1, figsize = (10,7))
ax1.stem(df['SepalLengthCm'],df['PetalLengthCm'],'r--')
# Out:
# C:\Users\Checkout\AppData\Local\Temp\ipykernel_13284\1096258760.py:2: MatplotlibDeprecationWarning: Passing the linefmt parameter positionally is deprecated since Matplotlib 3.5; the parameter will become keyword-only two minor releases later.
#   ax1.stem(df['SepalLengthCm'],df['PetalLengthCm'],'r--')
# <StemContainer object of 3 artists>

# %%
fig, ax2 = plt.subplots(1,1, figsize = (10,7))
ax2.fill_between(df['Species'],df['PetalLengthCm'])

# %%
fig, ax3 = plt.subplots(1,1, figsize = (10,7))
ax3.step(df['PetalLengthCm'],df['SepalLengthCm'])

# %%
df1 = pd.read_csv("Avg_World_Temp_2020.csv")
df1
# Out:
#      Unnamed: 0    Country         City   Jan   Feb   Mar   Apr   May   Jun  \
# 0             0    Algeria      Algiers  11.2  11.9  12.8  14.7  17.7  21.3
# 1             1    Algeria  Tamanrasset  12.8  15.0  18.1  22.2  26.1  28.9
# 2             2    Algeria      Reggane  16.0  18.2  23.1  27.9  32.2  36.4
# 3             3     Angola       Luanda  26.7  28.5  28.6  28.2  27.0  23.9
# 4             4      Benin      Cotonou  27.3  28.5  28.9  28.6  27.8  26.5
# ..          ...        ...          ...   ...   ...   ...   ...   ...   ...
# 419         419       Peru         Lima  22.1  22.7  22.2  20.6  18.8  17.5
# 420         420       Peru        Piura  26.8  27.8  27.8  26.6  24.5  22.9
# 421         421   Suriname   Paramaribo  26.0  26.0  26.2  26.7  26.5  26.5
# 422         422    Uruguay   Montevideo  23.0  22.5  20.6  17.2  14.0  11.1
# 423         423  Venezuela      Caracas  20.2  20.8  21.7  22.7  23.2  22.6
#
# ...

# %%
import seaborn as sns
# Explore what features influence thermal sensation
plt.figure(figsize=(20, 7))
sns.heatmap(df1.corr(), annot=True)

plt.title('FEATURES INFLUENCING THERMAL SENSATION')
# Out:
# Text(0.5, 1.0, 'FEATURES INFLUENCING THERMAL SENSATION')

# %%
from pylab import *
import matplotlib.pyplot as plt
df10 = df1.head(4)
df10
x = df10['Jan']
y = df10['Feb']

fig = plt.figure()
ax = fig.add_subplot(111)

scatter(x,y, s=100 ,marker='*')

[ plot( [dot_x,dot_x] ,[0,dot_y], '-', linewidth = 3 ) for dot_x,dot_y in zip(x,y) ] 
[ plot( [0,dot_x] ,[dot_y,dot_y], '-', linewidth = 3 ) for dot_x,dot_y in zip(x,y) ]

left,right = ax.get_xlim()
low,high = ax.get_ylim()
arrow( left, 0, right -left, 0, length_includes_head = True, head_width = 0.15 )
arrow( 0, low, 0, high-low, length_includes_head = True, head_width = 0.15 ) 

grid()

show()

# %%
t1 = df10['Dec']
t2 = df10['Nov']
t3 = df10['Apr']
plt.subplot()
plt.plot(t1, t2, 'r*', t2, t1, 'k--',t3,t1,'g^')
plt.grid(color='b', alpha=0.5, linestyle='dashed', linewidth=0.5)
plt.show()

# %%
df12=df1.head(20)
df12
# Out:
#     Unnamed: 0                   Country            City   Jan   Feb   Mar  \
# 0            0                   Algeria         Algiers  11.2  11.9  12.8
# 1            1                   Algeria     Tamanrasset  12.8  15.0  18.1
# 2            2                   Algeria         Reggane  16.0  18.2  23.1
# 3            3                    Angola          Luanda  26.7  28.5  28.6
# 4            4                     Benin         Cotonou  27.3  28.5  28.9
# 5            5                     Benin         Parakou  26.5  28.7  29.6
# 6            6                     Benin    Kandi, Benin  24.9  27.8  30.9
# 7            7                  Botswana  Maun, Botswana  25.4  25.1  24.2
# 8            8                  Botswana        Gaborone  26.0  25.0  24.0
# 9            9                  Botswana          Ghanzi  25.9  25.3  24.1
# 10          10              Burkina Faso     Ouagadougou  24.8  27.7  30.9
# ...

# %%
a=df12['Country']
b=df12['Feb']
plt.barh(a,b)
# Out:
# <BarContainer object of 20 artists>

# %%
df13=df1.head(3)
c = df13['Jan']
d = df13['Mar']
e = df13['May']
f = df13['Jul']
plt.stackplot(c,d,color='green', linewidth=3)
plt.stackplot(e,f,color='blue', linewidth=3)
plt.stackplot(d,c,color='red', linewidth=3)

# %%
dist_1 = df12['Jan']
dist_2 = df12['Aug']
fig, ax = plt.subplots(tight_layout=True)
hist = ax.hist2d(dist_1, dist_2)

# %%
data = np.concatenate((df12['Jan'],df12['Feb'],df12['Nov'],df12['Dec']))
fig1, ax1 = plt.subplots()
ax1.set_title('Basic Plot')
ax1.boxplot(data)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1b573c880a0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1b573c88640>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1b573c79d90>],
#  'medians': [<matplotlib.lines.Line2D at 0x1b573c88be0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1b573c88eb0>],
#  'means': []}

# %%
data = np.concatenate((df12['Jan'], df12['Dec']))
fig1, ax1 = plt.subplots()
ax1.set_title('Basic Plot')
ax1.violinplot(data)
# Out:
# {'bodies': [<matplotlib.collections.PolyCollection at 0x1b573cdcf40>],
#  'cmaxes': <matplotlib.collections.LineCollection at 0x1b573cdceb0>,
#  'cmins': <matplotlib.collections.LineCollection at 0x1b573cec640>,
#  'cbars': <matplotlib.collections.LineCollection at 0x1b573ceca00>}

# %%
x9 = df12['Jan']
y9 = df12['Jul']
e1 = 0.1 * np.abs(np.random.randn(len(y9)))
plt.errorbar(x9, y9, fmt = '.--',yerr = e1)
plt.show();
